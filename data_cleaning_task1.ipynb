# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\anagh\Downloads\Housing.xlsx.xls")
df
# Out:
#          price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0   133-00-000   7420         4          2        3      yes        no
# 1   12/250/000   8960         4          4        4      yes         n
# 2   122|500|00   9960         3          2        2      yes        no
# 3     12215000   7500         4          2        2      yes        no
# 4     11410000   7420         4          1        2      yes         y
# 5     10850000   7500         3          3        1      yes        no
# 6   101|500|00   8580         4          3        4      yes        no
# 7     10150000  16200         5          3        2      yes        no
# 8      9870000   8100         4          1        2      yes       yes
# 9      9800000   5750         3          2        4      yes         y
# 10     9800000  13200         3          1        2      yes        no
# 11     9681000   6000         4          3        2      yes       yes
# ...

# %%
df= df.drop_duplicates()
df
# Out:
#          price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0   133-00-000   7420         4          2        3      yes        no
# 1   12/250/000   8960         4          4        4      yes         n
# 2   122|500|00   9960         3          2        2      yes        no
# 3     12215000   7500         4          2        2      yes        no
# 4     11410000   7420         4          1        2      yes         y
# 5     10850000   7500         3          3        1      yes        no
# 6   101|500|00   8580         4          3        4      yes        no
# 7     10150000  16200         5          3        2      yes        no
# 8      9870000   8100         4          1        2      yes       yes
# 9      9800000   5750         3          2        4      yes         y
# 10     9800000  13200         3          1        2      yes        no
# 11     9681000   6000         4          3        2      yes       yes
# ...

# %%
df = df.copy()
df['price'] = df['price'].astype(str).str.replace(r'[^\d]', '', regex=True).astype(int)

# %%
df['status'] = df['status'].str.replace(r'[_\.…]+', '', regex=True)
df
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0   13300000   7420         4          2        3      yes        no       no
# 1   12250000   8960         4          4        4      yes         n       no
# 2   12250000   9960         3          2        2      yes        no      yes
# 3   12215000   7500         4          2        2      yes        no      yes
# 4   11410000   7420         4          1        2      yes         y      yes
# 5   10850000   7500         3          3        1      yes        no      yes
# 6   10150000   8580         4          3        4      yes        no       no
# 7   10150000  16200         5          3        2      yes        no       no
# 8    9870000   8100         4          1        2      yes       yes      yes
# 9    9800000   5750         3          2        4      yes         y       no
# 10   9800000  13200         3          1        2      yes        no      yes
# ...

# %%
columns_to_fix = ['guestroom', 'airconditioning', 'basement']
for col in columns_to_fix:
    df[col] = df[col].replace({'y': 'yes', 'n': 'no'})
for col in columns_to_fix:
    print(f"{col} unique values:", df[col].unique())
df
# Out:
# guestroom unique values: ['no' 'yes']
# airconditioning unique values: ['yes' 'no']
# basement unique values: ['no' 'yes']
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0   13300000   7420         4          2        3      yes        no       no
# 1   12250000   8960         4          4        4      yes        no       no
# 2   12250000   9960         3          2        2      yes        no      yes
# 3   12215000   7500         4          2        2      yes        no      yes
# 4   11410000   7420         4          1        2      yes       yes      yes
# 5   10850000   7500         3          3        1      yes        no      yes
# 6   10150000   8580         4          3        4      yes        no       no
# 7   10150000  16200         5          3        2      yes        no       no
# 8    9870000   8100         4          1        2      yes       yes      yes
# ...

# %%
df.to_csv("cleaned_housing_data.csv", index=False)
